# %% [markdown]
# In this exercise, we're going to be generating random numbers from various distributions, histogramming those numbers, and plotting the shapes of the probability distributions.  There are actually several different ways to do this.  In particular, `numpy` provides a function `numpy.histogram` which calculates a histogram from a list of values and some information about what the histogram bins should be.  `matplotlib` also provides a function to make and plot a histogram (`plt.hist`) as we all as display as a bar graph a previously calculated histogram (`plt.bar`).  I generally favor generating the histogram with `numpy.histogram` so I have the actual values, and can manipulate them, and then plot them as I like using `plt.bar`.
#
# Similarly, `numpy` provides ways of generating random numbers from various distributions, but the most systematic package for handling statistical distributions is `scipy.stats`, so we'll use it.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
mu = 5
sd = np.sqrt(mu)
N = 1000
# Generate random numbers from a distribution
poisson = stats.poisson.rvs(mu, size=N)

# %%
x = np.arange(15) 
h, be = np.histogram(photons_per_second, bins = x, density=True)
# Note that h and be don't have the same dimension!
def Bin(edge):
    centers = (edge[1:]+edge[0:-1])/2.
    return centers

# %%
plt.bar(Bin(be), h, width=1)
plt.plot(x,stats.poisson.pmf(np.array(x, dtype='int64'), mu),color='orange')
plt.plot(x,stats.norm.pdf(x,mu,np.sqrt(mu)),color='green')
