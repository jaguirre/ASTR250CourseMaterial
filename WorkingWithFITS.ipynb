# %% [markdown]
# How to create FITS image file from scratch, including the WCS
#
# https://docs.astropy.org/en/stable/io/fits/#creating-a-new-fits-file
#
# https://docs.astropy.org/en/stable/wcs/#building-a-wcs-structure-programmatically

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS

# %%
#hdu = fits.PrimaryHDU(data)
#hdu.writeto('simulated_image.fits')

# %%
testfile = '/Users/jaguirre/Documents/Teaching/ASTR250/Spring2020/m37sao.fits'

# %%
hdu = fits.open(testfile)[1]
m37_header = hdu.header
m37_image = hdu.data
m37_wcs = WCS(m37_header)

# %%
# %matplotlib notebook
#plt.figure(figsize=(10,10))
plt.subplot(projection = m37_wcs)
plt.imshow(hdu.data)
plt.colorbar(shrink=0.8)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.colorbar?
